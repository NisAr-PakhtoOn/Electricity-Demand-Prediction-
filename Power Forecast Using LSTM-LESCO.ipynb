# %%
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
pd.pandas.set_option("display.max_columns",None)
#pd.pandas.set_option("display.max_rows",None)

# %%
data=pd.read_csv("dates2.csv")

# %%
data
# Out:
#            date2  QUOTA ALLOCATED   LOAD DRAWN (MW)  \
# 0       1/1/2017            34873             34910
# 1       1/2/2017            30143             35086
# 2       1/3/2017            32783             38132
# 3       1/4/2017            33532             39435
# 4       1/5/2017            34076             40535
# ...          ...              ...               ...
# 1821  12/27/2021            65383             58255
# 1822  12/28/2021            65386             60150
# 1823  12/29/2021            65609             61254
# 1824  12/30/2021            65764             60989
# 1825  12/31/2021            65416             60801
#
#       LAOD SHEDDING (MW) (LOAD MANAGEMENT)  TOTAL DEMAND (MW)
# 0                                     4292               39202
# 1                                     6150               41236
# 2                                     6132               44264
# 3                                     5555               44990
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1826 entries, 0 to 1825
# Data columns (total 5 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   date2                                 1826 non-null   object
#  1   QUOTA ALLOCATED                       1826 non-null   int64
#  2    LOAD DRAWN (MW)                      1826 non-null   int64
#  3   LAOD SHEDDING (MW) (LOAD MANAGEMENT)  1826 non-null   int64
#  4   TOTAL DEMAND (MW)                     1826 non-null   int64
# dtypes: int64(4), object(1)
# memory usage: 71.5+ KB

# %%
data["Month"] = pd.to_datetime(data["date2"]).dt.month
data["Year"] = pd.to_datetime(data["date2"]).dt.year

# %%
data
# Out:
#            date2  QUOTA ALLOCATED   LOAD DRAWN (MW)  \
# 0       1/1/2017            34873             34910
# 1       1/2/2017            30143             35086
# 2       1/3/2017            32783             38132
# 3       1/4/2017            33532             39435
# 4       1/5/2017            34076             40535
# ...          ...              ...               ...
# 1821  12/27/2021            65383             58255
# 1822  12/28/2021            65386             60150
# 1823  12/29/2021            65609             61254
# 1824  12/30/2021            65764             60989
# 1825  12/31/2021            65416             60801
#
#       LAOD SHEDDING (MW) (LOAD MANAGEMENT)  TOTAL DEMAND (MW)   Month  Year
# 0                                     4292               39202      1  2017
# 1                                     6150               41236      1  2017
# 2                                     6132               44264      1  2017
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
# How many Unique Year do we Have in Dataset 
print(data.Year.unique(),"\n")
print("Total Number of Unique Year", data.Year.nunique(), "\n")
# Out:
# [2017 2018 2019 2020 2021]
#
# Total Number of Unique Year 5

# %%
from matplotlib import style

fig = plt.figure()
ax1 = plt.subplot2grid((1,1), (0,0))

style.use('ggplot')

sns.lineplot(x=data["Year"], y=data["TOTAL DEMAND (MW) "], data=data)
sns.set(rc={'figure.figsize':(15,2)})

plt.title("Energy consumption Per Year")
plt.xlabel("Date")
plt.ylabel("Energy in MW")
plt.grid(True)
plt.legend()

for label in ax1.xaxis.get_ticklabels():
    label.set_rotation(90)


plt.title("Energy Consumption According to Year")
# Out:
# No handles with labels found to put in legend.
# Text(0.5, 1.0, 'Energy Consumption According to Year')

# %% [markdown]
# # Energy Distribution

# %%
sns.distplot(data["TOTAL DEMAND (MW) "])
plt.title("TOTAL DEMAND (MW) ")
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'TOTAL DEMAND (MW) ')

# %% [markdown]
# # Feature Engineering

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1826 entries, 0 to 1825
# Data columns (total 5 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   date2                                 1826 non-null   object
#  1   QUOTA ALLOCATED                       1826 non-null   int64
#  2    LOAD DRAWN (MW)                      1826 non-null   int64
#  3   LAOD SHEDDING (MW) (LOAD MANAGEMENT)  1826 non-null   int64
#  4   TOTAL DEMAND (MW)                     1826 non-null   int64
# dtypes: int64(4), object(1)
# memory usage: 71.5+ KB

# %%
data['date2'] = pd.to_datetime(data['date2'])

# %%
import datetime as dt

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1826 entries, 0 to 1825
# Data columns (total 5 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   date2                                 1826 non-null   datetime64[ns]
#  1   QUOTA ALLOCATED                       1826 non-null   int64
#  2    LOAD DRAWN (MW)                      1826 non-null   int64
#  3   LAOD SHEDDING (MW) (LOAD MANAGEMENT)  1826 non-null   int64
#  4   TOTAL DEMAND (MW)                     1826 non-null   int64
# dtypes: datetime64[ns](1), int64(4)
# memory usage: 71.5 KB

# %%
data['date2']=data['date2'].apply(lambda x: x.strftime('%Y/%m/%d'))

# %%
data.head(5)
# Out:
#         date2  QUOTA ALLOCATED   LOAD DRAWN (MW)  \
# 0  2017/01/01            34873             34910
# 1  2017/01/02            30143             35086
# 2  2017/01/03            32783             38132
# 3  2017/01/04            33532             39435
# 4  2017/01/05            34076             40535
#
#    LAOD SHEDDING (MW) (LOAD MANAGEMENT)  TOTAL DEMAND (MW)
# 0                                  4292               39202
# 1                                  6150               41236
# 2                                  6132               44264
# 3                                  5555               44990
# 4                                  5074               45609

# %%
data['date2'] = pd.to_datetime(data['date2'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1826 entries, 0 to 1825
# Data columns (total 5 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   date2                                 1826 non-null   datetime64[ns]
#  1   QUOTA ALLOCATED                       1826 non-null   int64
#  2    LOAD DRAWN (MW)                      1826 non-null   int64
#  3   LAOD SHEDDING (MW) (LOAD MANAGEMENT)  1826 non-null   int64
#  4   TOTAL DEMAND (MW)                     1826 non-null   int64
# dtypes: datetime64[ns](1), int64(4)
# memory usage: 71.5 KB

# %%
data.set_index(["date2"],inplace=True)

# %%
data.head()
# Out:
#             QUOTA ALLOCATED   LOAD DRAWN (MW)  \
# date2
# 2017-01-01            34873             34910
# 2017-01-02            30143             35086
# 2017-01-03            32783             38132
# 2017-01-04            33532             39435
# 2017-01-05            34076             40535
#
#             LAOD SHEDDING (MW) (LOAD MANAGEMENT)  TOTAL DEMAND (MW)
# date2
# 2017-01-01                                  4292               39202
# 2017-01-02                                  6150               41236
# 2017-01-03                                  6132               44264
# 2017-01-04                                  5555               44990
# 2017-01-05                                  5074               45609

# %%
data=data.astype('float')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1826 entries, 2017-01-01 to 2021-12-31
# Data columns (total 4 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   QUOTA ALLOCATED                       1826 non-null   float64
#  1    LOAD DRAWN (MW)                      1826 non-null   float64
#  2   LAOD SHEDDING (MW) (LOAD MANAGEMENT)  1826 non-null   float64
#  3   TOTAL DEMAND (MW)                     1826 non-null   float64
# dtypes: float64(4)
# memory usage: 71.3 KB

# %% [markdown]
# # Splitting Data

# %%
data_train=data.loc[:'2020-12-31',:]["TOTAL DEMAND (MW) "]

# %%
data_train.head(20)
# Out:
# date2
# 2017-01-01    39202.0
# 2017-01-02    41236.0
# 2017-01-03    44264.0
# 2017-01-04    44990.0
# 2017-01-05    45609.0
# 2017-01-06    45034.0
# 2017-01-07    44997.0
# 2017-01-08    39828.0
# 2017-01-09    43047.0
# 2017-01-10    45932.0
# 2017-01-11    46394.0
# 2017-01-12    45274.0
# 2017-01-13    46504.0
# 2017-01-14    45815.0
# 2017-01-15    40212.0
# 2017-01-16    40944.0
# 2017-01-17    46272.0
# 2017-01-18    47687.0
# 2017-01-19    47551.0
# 2017-01-20    48978.0
# Name: TOTAL DEMAND (MW) , dtype: float64

# %%
data_test=data['2021']["TOTAL DEMAND (MW) "]
# Out:
# <ipython-input-186-f623e0882d96>:1: FutureWarning: Indexing a DataFrame with a datetimelike index using a single string to slice the rows, like `frame[string]`, is deprecated and will be removed in a future version. Use `frame.loc[string]` instead.
#   data_test=data['2021']["TOTAL DEMAND (MW) "]

# %%
data_train.shape,data_test.shape
# Out:
# ((1461,), (365,))

# %%
data_train
# Out:
# date2
# 2017-01-01    39202.0
# 2017-01-02    41236.0
# 2017-01-03    44264.0
# 2017-01-04    44990.0
# 2017-01-05    45609.0
#                ...
# 2020-12-27    58647.0
# 2020-12-28    58647.0
# 2020-12-29    58647.0
# 2020-12-30    52735.0
# 2020-12-31    53108.0
# Name: TOTAL DEMAND (MW) , Length: 1461, dtype: float64

# %% [markdown]
# # Preparing Training Data

# %%
data_train=np.array(data_train)

# %%
x_train,y_train=[],[]

for i in range(30,len(data_train)-30):
    x_train.append(data_train[i-30:i])
    
    y_train.append(data_train[i:i+30])

# %%
x_train,y_train=np.array(x_train),np.array(y_train)

# %%
x_train.shape,y_train.shape
# Out:
# ((1401, 30), (1401, 30))

# %%
pd.DataFrame(y_train)
# Out:
#             0        1        2        3        4        5        6        7   \
# 0     126507.0  45660.0  46075.0  46095.0  44722.0  38782.0  45777.0  45777.0
# 1      45660.0  46075.0  46095.0  44722.0  38782.0  45777.0  45777.0  46628.0
# 2      46075.0  46095.0  44722.0  38782.0  45777.0  45777.0  46628.0  46876.0
# 3      46095.0  44722.0  38782.0  45777.0  45777.0  46628.0  46876.0  47009.0
# 4      44722.0  38782.0  45777.0  45777.0  46628.0  46876.0  47009.0  46475.0
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 1396   58647.0  58647.0  58647.0  58647.0  58647.0  58647.0  58647.0  58647.0
# 1397   58647.0  58647.0  58647.0  58647.0  58647.0  58647.0  58647.0  58647.0
# 1398   58647.0  58647.0  58647.0  58647.0  58647.0  58647.0  58647.0  58647.0
# 1399   58647.0  58647.0  58647.0  58647.0  58647.0  58647.0  58647.0  58647.0
# 1400   58647.0  58647.0  58647.0  58647.0  58647.0  58647.0  58647.0  58647.0
#
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
x_scaler=MinMaxScaler()

x_train=x_scaler.fit_transform(x_train)

# %%
pd.DataFrame(x_train)
# Out:
#             0         1         2         3         4         5         6   \
# 0     0.303021  0.319259  0.343432  0.349228  0.354170  0.349579  0.349284
# 1     0.319259  0.343432  0.349228  0.354170  0.349579  0.349284  0.308018
# 2     0.343432  0.349228  0.354170  0.349579  0.349284  0.308018  0.333717
# 3     0.349228  0.354170  0.349579  0.349284  0.308018  0.333717  0.356748
# 4     0.354170  0.349579  0.349284  0.308018  0.333717  0.356748  0.360437
# ...        ...       ...       ...       ...       ...       ...       ...
# 1396  0.458255  0.458255  0.458255  0.458255  0.458255  0.458255  0.458255
# 1397  0.458255  0.458255  0.458255  0.458255  0.458255  0.458255  0.458255
# 1398  0.458255  0.458255  0.458255  0.458255  0.458255  0.458255  0.458255
# 1399  0.458255  0.458255  0.458255  0.458255  0.458255  0.458255  0.458255
# 1400  0.458255  0.458255  0.458255  0.458255  0.458255  0.458255  0.458255
#
# ...

# %%
y_scaler=MinMaxScaler()

y_train=y_scaler.fit_transform(y_train)

# %%
y_train
# Out:
# array([[1.        , 0.4231088 , 0.4270622 , ..., 0.44370457, 0.44854391,
#         0.45472645],
#        [0.35457681, 0.4270622 , 0.42725272, ..., 0.44854391, 0.45472645,
#         0.4586608 ],
#        [0.35788986, 0.42725272, 0.41417317, ..., 0.45472645, 0.4586608 ,
#         0.45724139],
#        ...,
#        [0.4582555 , 0.54682633, 0.54682633, ..., 0.54682633, 0.54682633,
#         0.54682633],
#        [0.4582555 , 0.54682633, 0.54682633, ..., 0.54682633, 0.54682633,
#         0.54682633],
#        [0.4582555 , 0.54682633, 0.54682633, ..., 0.54682633, 0.54682633,
#         0.49050708]])

# %%
x_train.shape
# Out:
# (1401, 30)

# %%
x_train=x_train.reshape(1401,30,1)

# %%
x_train.shape
# Out:
# (1401, 30, 1)

# %% [markdown]
# # Build LSTM MODEL

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import LSTM,Dense

# %%
reg=Sequential()


reg.add(LSTM(units=200,activation='relu',input_shape=(30,1)))
reg.add(Dense(30))

# %%
reg.compile(loss='mse',optimizer='adam')

# %%
reg.fit(x_train,y_train,epochs=100 )
# Out:
# Epoch 1/100
# 44/44 [==============================] - 2s 19ms/step - loss: 0.2376
# Epoch 2/100
# 44/44 [==============================] - 1s 17ms/step - loss: 0.0261
# Epoch 3/100
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0157
# Epoch 4/100
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0146
# Epoch 5/100
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0141
# Epoch 6/100
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0132
# Epoch 7/100
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0137
# Epoch 8/100
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0132
# Epoch 9/100
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0122
# Epoch 10/100
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0119
# Epoch 11/100
# 44/44 [==============================] - 1s 15ms/step - loss: 0.0132
# Epoch 12/100
# ...

# %% [markdown]
# # Prepare Testing Data

# %%
data_test=np.array(data_test)

# %%
x_test,y_test=[],[]

for i in range(30,len(data_test)-30):
    
    x_test.append(data_test[i-30:i])
    y_test.append(data_test[i:i+30])

# %%
x_test,y_test=np.array(x_test),np.array(y_test)

# %%
x_test=x_scaler.transform(x_test)
y_test=y_scaler.transform(y_test)

# %%
x_test.shape
# Out:
# (305, 30)

# %%
x_test=x_test.reshape(305,30,1)

# %% [markdown]
# # Predictions

# %%
y_pred=reg.predict(x_test)
y_pred
# Out:
# array([[0.41006148, 0.49356893, 0.5016956 , ..., 0.53282905, 0.5333373 ,
#         0.54732937],
#        [0.40936548, 0.49347147, 0.5018803 , ..., 0.5344722 , 0.53491473,
#         0.548801  ],
#        [0.40648952, 0.49158886, 0.5006352 , ..., 0.5358802 , 0.5361552 ,
#         0.5500993 ],
#        ...,
#        [0.5157759 , 0.6151093 , 0.6240084 , ..., 0.710063  , 0.70936596,
#         0.72213596],
#        [0.51734245, 0.617229  , 0.6260446 , ..., 0.7121405 , 0.7115619 ,
#         0.7239496 ],
#        [0.5200247 , 0.6205158 , 0.62936026, ..., 0.71431553, 0.71392465,
#         0.7260836 ]], dtype=float32)

# %%
Predicted_Values=y_scaler.inverse_transform(y_pred)
Predicted_Values
# Out:
# array([[52610.12 , 53056.414, 53909.49 , ..., 57177.664, 57231.016,
#         58699.805],
#        [52522.938, 53046.184, 53928.88 , ..., 57350.152, 57396.605,
#         58854.29 ],
#        [52162.69 , 52848.56 , 53798.18 , ..., 57497.953, 57526.82 ,
#         58990.574],
#        ...,
#        [65852.125, 65814.87 , 66749.04 , ..., 75782.44 , 75709.27 ,
#         77049.78 ],
#        [66048.35 , 66037.375, 66962.77 , ..., 76000.52 , 75939.79 ,
#         77240.164],
#        [66384.336, 66382.41 , 67310.836, ..., 76228.84 , 76187.81 ,
#         77464.17 ]], dtype=float32)

# %%
Actual_values=y_scaler.inverse_transform(y_test)
Actual_values
# Out:
# array([[48923., 47517., 49380., ..., 50536., 52783., 47469.],
#        [47517., 49380., 49939., ..., 52783., 47469., 52455.],
#        [49380., 49939., 50021., ..., 47469., 52455., 53329.],
#        ...,
#        [59273., 60048., 59970., ..., 54339., 60468., 62791.],
#        [60048., 59970., 59464., ..., 60468., 62791., 63285.],
#        [59970., 59464., 59325., ..., 62791., 63285., 63016.]])

# %% [markdown]
# # Evaluating MODEL

# %%
from sklearn.metrics import mean_squared_error

# %%
def evaluate(y_true,y_pred):
    
    scores=[]
    
    for i in range(y_true.shape[1]):
        mse=mean_squared_error(y_true[:, i], y_pred[:, i])
        rmse=np.sqrt(mse)
        
        scores.append(rmse)
    total_score=[]    
    for row in range(y_true.shape[0]):
        for col in range(y_pred.shape[1]):
            total_score=total_score + (y_true[row, col]- y_pred[row,col])**2
    total_score=np.sqrt(total_score/(y_true.shape[0]*y_pred.shape[1]))
    
    return total_score,scores

# %%
evaluate(y_true,y_pred)
# Out:
# (array([], dtype=float64),
#  [77478.23707809484,
#   77499.78328096415,
#   77521.20610501358,
#   77548.20583817345,
#   77551.95928042619,
#   77554.83743939486,
#   77544.79538106763,
#   77544.43713629022,
#   77543.692074883,
#   77534.018598687,
#   77527.09289043576,
#   77551.11842478605,
#   77577.39729358912,
#   77600.33636180099,
#   77630.81189549608,
#   77670.57069064851,
#   77703.34055182988,
#   77735.00925162452,
#   77765.99055634014,
#   77784.78687471597,
#   77800.60222491226,
#   77828.14113513181,
#   77857.51865067697,
#   77887.4203970395,
#   77918.37174476619])
